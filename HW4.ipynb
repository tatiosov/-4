# %% [markdown]
# ###Основы языка Python для аналитиков (семинары), Home work 4

# %% [markdown]
# **Условие 1: Задача 1**
#
# Постройте график
#
# Назовите график
#
# Сделайте именование оси x и оси y
#
# Сделайте выводы

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# > 1.1. Скачать следующие данные: kc-house-data и laptop_price

# %%
pd.options.display.float_format = '{:20,.2f}'.format
pd.read_csv('/content/drive/MyDrive/kc-house-data (1).csv')
df
# Out:
#                id             date                price  bedrooms  \
# 0      7129300520  20141013T000000           221,900.00         3
# 1      6414100192  20141209T000000           538,000.00         3
# 2      5631500400  20150225T000000           180,000.00         2
# 3      2487200875  20141209T000000           604,000.00         4
# 4      1954400510  20150218T000000           510,000.00         3
# ...           ...              ...                  ...       ...
# 21608   263000018  20140521T000000           360,000.00         3
# 21609  6600060120  20150223T000000           400,000.00         4
# 21610  1523300141  20140623T000000           402,101.00         2
# 21611   291310100  20150116T000000           400,000.00         3
# 21612  1523300157  20141015T000000           325,000.00         2
#
#                  bathrooms  sqft_living  sqft_lot               floors  view  \
# 0                     1.00         1180      5650                 1.00     0
# 1                     2.25         2570      7242                 2.00     0
# 2                     1.00          770     10000                 1.00     0
# 3                     3.00         1960      5000                 1.00     0
# 4                     2.00         1680      8080                 1.00     0
# ...                    ...          ...       ...                  ...   ...
# 21608                 2.50         1530      1131                 3.00     0
# 21609                 2.50         2310      5813                 2.00     0
# 21610                 0.75         1020      1350                 2.00     0
# 21611                 2.50         1600      2388                 2.00     0
# 21612                 0.75         1020      1076                 2.00     0
#
#        condition  ...  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0              3  ...        1180              0      1955             0
# 1              3  ...        2170            400      1951          1991
# 2              3  ...         770              0      1933             0
# 3              5  ...        1050            910      1965             0
# 4              3  ...        1680              0      1987             0
# ...          ...  ...         ...            ...       ...           ...
# 21608          3  ...        1530              0      2009             0
# 21609          3  ...        2310              0      2014             0
# 21610          3  ...        1020              0      2009             0
# 21611          3  ...        1600              0      2004             0
# 21612          3  ...        1020              0      2008             0
#
#        zipcode                  lat                 long  sqft_living15  \
# 0        98178                47.51              -122.26           1340
# 1        98125                47.72              -122.32           1690
# 2        98028                47.74              -122.23           2720
# 3        98136                47.52              -122.39           1360
# 4        98074                47.62              -122.05           1800
# ...        ...                  ...                  ...            ...
# 21608    98103                47.70              -122.35           1530
# 21609    98146                47.51              -122.36           1830
# 21610    98144                47.59              -122.30           1020
# 21611    98027                47.53              -122.07           1410
# 21612    98144                47.59              -122.30           1020
#
#        sqft_lot15  is_waterfront
# 0            5650          False
# 1            7639          False
# 2            8062          False
# 3            5000          False
# 4            7503          False
# ...           ...            ...
# 21608        1509          False
# 21609        7200          False
# 21610        2007          False
# 21611        1287          False
# 21612        1357          False
#
# [21613 rows x 21 columns]

# %% [markdown]
# > 1.2. Изучите стоимости недвижимости

# %%
plt.figure(figsize = (6,4))
plt.hist(df['price'], bins = 10)
plt.xlabel('Стоимость')
plt.ylabel('Количество')
plt.title('Стоимость недвижимости');

# %%
plt.figure(figsize=(6,8))
plt.hist(df['price'], bins=100)
plt.title('Стоимость недвижимости')
plt.xlabel('Цена')
plt.ylabel('Количество');

# %% [markdown]
# > 1.3. Изучите распределение квадратуры жилой

# %%
plt.figure(figsize = (6,4))
sns.histplot(df['sqft_living'], bins = 10)
plt.xlabel('Жилые квадратные метры')
plt.ylabel('Количество')
plt.title('Распределение жилой квадратуры');

# %% [markdown]
# > 1.4. Изучите распределение года постройки

# %% [markdown]
# **Условие 2: 2 задача**

# %% [markdown]
# > 2.1. Изучите распределение домов от наличия вида на набережную
#
# Постройте график
#
# Сделайте выводы

# %%
df = pd.read_csv('/content/drive/MyDrive/kc-house-data (1).csv')
data_view = df['waterfront'].value_counts()
val = data_view.values
plt.pie(val,labels=['without seaview', 'seaview'],explode=[0,0.3],
        radius = 1.5, startangle=60,
        labeldistance=1.2, autopct='%.1f%%');

# %% [markdown]
# > 2.2. Изучите распределение этажей домов

# %%
df.floors.max(), df.floors.min()
# Out:
# (3.5, 1.0)

# %%
data2 = df['floors'].value_counts(normalize=True)*100
data2
# Out:
# 1.00                  49.41
# 2.00                  38.13
# 1.50                   8.84
# 3.00                   2.84
# 2.50                   0.74
# 3.50                   0.04
# Name: floors, dtype: float64

# %%
data_floor = df['floors'].value_counts()
f_val = data_floor.values
f_ind = data_floor.index
plt.figure(figsize=(12, 6))
plt.bar(f_ind,f_val, width=0.4, facecolor='c', alpha=0.75)
plt.title('Этажность')
plt.xlabel('Этажи')
plt.ylabel('Количество домов')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,8))
explode = [0.0, 0.1, 0.3, 0.5, 0.5, 0.5]
plt.pie(data2.values, autopct='%1.2f%%', labels=data2.index, explode=explode)
plt.legend(data2.index)
plt.title('Распределение этажей домов');

# %% [markdown]
# > 2.3. Изучите распределение состояния домов

# %%
plt.figure(figsize=(8, 6))
df['condition'].value_counts().plot(kind='bar')
plt.title('Распределение состояния домов')
plt.xlabel('Состояние')
plt.ylabel('Количество объектов')
plt.show()

# %% [markdown]
# **Условие 3: 3 задача**
#
#
# > Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
#
#
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
plt.figure(figsize=(15, 6))
plt.scatter(df['yr_built'], df['price'])
plt.title('Распределение средних цен в зависимости от года постройки');

# %%
plt.figure(figsize=(14, 10))
sns.boxplot(x=df['price'], y=df['waterfront'].astype('str'), whis=1.5, hue=df['grade'])

plt.title('Распределение цен по береговой линии')
plt.xlabel('Цена')
plt.ylabel('Наличия набережной');

# %%
plt.figure(figsize = (14,10))
sns.boxplot(x = df['price'], y = df['floors'].astype('str'), whis = 1.5)
plt.xlabel('Цена')
plt.ylabel('Этажность')
plt.title('Стоимость/Этажность дома');

# %%
plt.figure(figsize = (14,10))
sns.boxplot(x = df['price'], y = df['condition'].astype('str'), whis = 1.5)
plt.xlabel('Цена')
plt.ylabel('Состояние дома')
plt.title('Стоимость/Оценка состояния');
